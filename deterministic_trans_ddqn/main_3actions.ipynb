# %%
import random
import gymnasium as gym
from collections import namedtuple, deque
from itertools import count
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
BASE_MODEL_PATH = "ddqn_lunar_lander_base_actions.pth"
NUMBER_OF_EPISODES = 600

Transition = namedtuple(
    "Transition", ["state", "action", "next_state", "reward", "done"]
)
class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return (
            random.sample(self.memory, batch_size)
            if batch_size < len(self.memory)
            else self.memory
        )

    def __len__(self):
        return len(self.memory)

# %%
# !pip install swig
# !pip install "gymnasium[box2d]"

# %%
import torch.nn as nn
import torch.nn.functional as F


class DQN(nn.Module):
    def __init__(self, n_observations, n_actions):
        super().__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
class ActionMap():
    def __init__(self, action_map = {0:1, 1:2, 2:3}, expand_actions_env = []):
        self.action_map = action_map
        self.expand_actions_env = expand_actions_env
    
    def convert_action_env_to_network(self, action_env):
        for k, v in self.action_map.items():
            if v == action_env:
                return k
        return None
    
    def get_expand_actions_in_network(self):
        result = []
        for key, value in self.action_map.items():
            if value in self.expand_actions_env:
                result.append(key)
        return result
    
    def convert_network_action_to_env(self, action_network):
        return self.action_map.get(action_network, None)
    
    def select_all_actions_in_network(self):
        return list(self.action_map.keys())
    
    def select_all_actions_in_env(self):
        return list(self.action_map.values())

# %%
EXPANDED_ACTION = 0
base_action_map = ActionMap({0:1, 1:2, 2: 3})
full_action_map = ActionMap({0:0, 1:1, 2:2, 3:3}, expand_actions_env=[EXPANDED_ACTION])

# %%
test = ActionMap({0:0, 1:1, 2:2, 3:3}, expand_actions_env=[0, 2,3])
print(test.get_expand_actions_in_network())
# Out:
# [0, 2, 3]

# %%
class DDQNAgent:
    def __init__(self, n_observation, action_data: ActionMap, batch_size=128, gamma=0.99, lr=1e-4, tau=0.005):
        action_len = len(action_data.action_map.keys())
        self.batch_size = batch_size
        self.GAMMA = gamma
        self.LR = lr
        self.TAU = tau
        self.action_map = action_data
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(n_observations= n_observation, n_actions= action_len).to(self.device)
        self.target_net = DQN(n_observations= n_observation, n_actions= action_len).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.replay_memory = ReplayMemory(10000)
        self.reward_list = []
        self.episode_duration = []
        self.optimizer = optim.AdamW(self.policy_net.parameters(), lr=self.LR)
        self.criterion = nn.SmoothL1Loss()
        self.EPSILON = 1.0
        self.EPSILON_MIN = 0.01
        self.EPSILON_DECAY = 0.995
        
    def select_action(self, state, epsilon):
        if np.random.rand() < epsilon:
            action = np.random.choice(self.action_map.select_all_actions_in_network())
            return torch.tensor([[action]], dtype=torch.long, device=self.device)
        else:
            with torch.no_grad():
                return self.policy_net(state).max(1).indices.view(1, 1) # max row (1), max col (0)
            
    def train(self, env, num_episodes):
        for episode in range(num_episodes):
            total_reward = 0
            state, _ = env.reset()
            state = torch.tensor(
                state, dtype=torch.float32, device=self.device
            ).unsqueeze(0)
            for t in count():
                
                action = self.select_action(state, self.EPSILON)
                env_action = self.action_map.convert_network_action_to_env(action.item())
                next_state, reward, terminated, truncated, info = env.step(env_action)
                done = terminated or truncated
                reward = torch.tensor([reward], device=self.device)
                next_state = torch.tensor(
                    next_state, dtype=torch.float32, device=self.device
                ).unsqueeze(0)
                self.replay_memory.push(state, action, next_state, reward, done)
                state = next_state
                total_reward += reward.item()
                if len(self.replay_memory) >= self.batch_size:
                    transitions = self.replay_memory.sample(self.batch_size)
                    states, actions, next_states, rewards, dones = zip(*transitions) 
                    #convert tuple to tensor array
                    states_batch = torch.cat(states) # states is a tuple, now it becomes a batch (2D array)
                    next_states_batch = torch.cat(next_states)
                    actions_batch = torch.cat(actions)
                    
                    reward_batch = torch.tensor(rewards, device= self.device)
                    dones_batch = torch.tensor(dones, dtype=torch.float32, device=self.device)
                    
                    # Q-value which are estimating (policy network)
                    q_values = self.policy_net(states_batch).gather(1, actions_batch).squeeze()
                    
                    # get target Q-values
                    with torch.no_grad():
                        next_q_values = self.target_net(next_states_batch).max(1).values
                        target_q_values = reward_batch + self.GAMMA * next_q_values * (1 - dones_batch)
                    loss = self.criterion(q_values, target_q_values) # prove converge
                    
                    self.optimizer.zero_grad()
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
                    self.optimizer.step()
                    
                    # soft update target network
                    for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
                        target_param.data.copy_(self.TAU * policy_param.data + (1 - self.TAU) * target_param.data)
                    
                if done:
                    self.episode_duration.append(t+1)
                    break
            
            # Decay epsilon    
            self.EPSILON = max(self.EPSILON_MIN, self.EPSILON * self.EPSILON_DECAY)
            self.reward_list.append(total_reward)
            
            if (episode + 1) % 10 == 0:
                avg_reward = np.mean(self.reward_list[-10:])
                print(f"Episode {episode+1}/{num_episodes}, Reward: {total_reward:.2f}, "
                    f"Avg10: {avg_reward:.2f}, Epsilon: {self.EPSILON:.3f}")                    
        
        torch.save(self.policy_net.state_dict(), BASE_MODEL_PATH)

# %% [markdown]
# ### Train the Transition Model

# %%
"""
Transition Model for Action 0 (NOOP/Nothing)
=============================================

This MLP predicts: s' = f(s, a=0)
Given current state s, predict next state s' when taking action 0 (do nothing).

The model learns from real transitions collected when action 0 is executed.
"""

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from collections import deque
import gymnasium as gym


class TransitionModelAction0(nn.Module):
    """
    MLP to predict next state for action 0 (NOOP).
    
    Input: state s (8-dim for LunarLander)
    Output: predicted next state s' (8-dim)
    
    Optionally outputs variance for uncertainty estimation.
    """
    
    def __init__(self, state_dim=8, hidden_dim=128, with_variance=True, dropout=0.2):
        super().__init__()
        
        self.state_dim = state_dim
        self.with_variance = with_variance
        
        # Shared layers with dropout for regularization
        self.fc1 = nn.Linear(state_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        
        # Dropout for regularization
        self.dropout = nn.Dropout(dropout)
        
        # Mean prediction (next state)
        self.fc_mean = nn.Linear(hidden_dim, state_dim)
        
        # Variance prediction (for uncertainty/confidence)
        if with_variance:
            self.fc_logvar = nn.Linear(hidden_dim, state_dim)
        
        self.relu = nn.ReLU()
        
    def forward(self, state):
        """
        Forward pass.
        
        Args:
            state: [batch, state_dim] or [state_dim]
            
        Returns:
            mean: predicted next state
            logvar: log variance (if with_variance=True)
        """
        if state.dim() == 1:
            state = state.unsqueeze(0)
            
        h = self.relu(self.fc1(state))
        h = self.dropout(h)
        h = self.relu(self.fc2(h))
        h = self.dropout(h)
        h = self.relu(self.fc3(h))
        h = self.dropout(h)
        
        mean = self.fc_mean(h)
        
        if self.with_variance:
            logvar = self.fc_logvar(h)
            return mean, logvar
        else:
            return mean
    
    def predict(self, state):
        """
        Predict next state with confidence.
        
        Returns:
            next_state: predicted next state
            confidence: confidence score (0 to 1, higher = more confident)
        """
        self.eval()
        with torch.no_grad():
            if isinstance(state, np.ndarray):
                state = torch.FloatTensor(state)
            if state.dim() == 1:
                state = state.unsqueeze(0)
            
            if self.with_variance:
                mean, logvar = self(state)
                # Confidence = exp(-mean_variance)
                variance = torch.exp(logvar)
                confidence = torch.exp(-variance.mean(dim=1))
                return mean.squeeze(0).numpy(), confidence.item()
            else:
                mean = self(state)
                return mean.squeeze(0).numpy(), 1.0


class TransitionDataCollector:
    """
    Collects (state, next_state) pairs for action 0.
    """
    
    def __init__(self, buffer_size=50000):
        self.buffer = deque(maxlen=buffer_size)
        
    def add(self, state, next_state):
        """Add a transition for action 0."""
        self.buffer.append((
            np.array(state).flatten(),
            np.array(next_state).flatten()
        ))
    
    def sample(self, batch_size):
        """Sample a batch of transitions."""
        if batch_size > len(self.buffer):
            batch_size = len(self.buffer)
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states = np.array([self.buffer[i][0] for i in indices])
        next_states = np.array([self.buffer[i][1] for i in indices])
        return states, next_states
    
    def __len__(self):
        return len(self.buffer)


class TransitionModelTrainer:
    """
    Trainer for the transition model.
    """
    
    def __init__(self, model, lr=1e-3, device='cpu'):
        self.model = model.to(device)
        self.device = device
        self.optimizer = optim.Adam(model.parameters(), lr=lr)
        self.data_collector = TransitionDataCollector()
        
    def add_transition(self, state, next_state):
        """Add observed transition for action 0."""
        self.data_collector.add(state, next_state)
        
    def train_step(self, batch_size=64):
        """Perform one training step."""
        if len(self.data_collector) < batch_size:
            return None
        
        states, next_states = self.data_collector.sample(batch_size)
        
        states = torch.FloatTensor(states).to(self.device)
        next_states = torch.FloatTensor(next_states).to(self.device)
        
        self.model.train()
        
        if self.model.with_variance:
            # Negative log-likelihood loss with learned variance
            mean, logvar = self.model(states)
            # NLL = 0.5 * (log(var) + (target - mean)^2 / var)
            loss = 0.5 * (logvar + (next_states - mean)**2 * torch.exp(-logvar)).mean()
        else:
            # Simple MSE loss
            mean = self.model(states)
            loss = nn.MSELoss()(mean, next_states)
        
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1.0)
        self.optimizer.step()
        
        return loss.item()
    
    def train_epochs(self, epochs=10, batch_size=64):
        """Train for multiple epochs."""
        if len(self.data_collector) < batch_size:
            return []
        
        losses = []
        for _ in range(epochs):
            loss = self.train_step(batch_size)
            if loss is not None:
                losses.append(loss)
        return losses
    
    def can_predict(self, min_samples=100):
        """Check if model has enough data to make predictions."""
        return len(self.data_collector) >= min_samples
    
    def save(self, path):
        """Save model weights."""
        torch.save(self.model.state_dict(), path)
        
    def load(self, path):
        """Load model weights."""
        self.model.load_state_dict(torch.load(path))


def collect_action0_data(num_episodes=100, save_path=None):
    """
    Collect transition data for action 0 by running random policy.
    
    Returns:
        data_collector: TransitionDataCollector with collected data
    """
    env = gym.make("LunarLander-v3")
    collector = TransitionDataCollector()
    
    total_action0_transitions = 0
    
    for ep in range(num_episodes):
        state, _ = env.reset()
        done = False
        
        while not done:
            # Random action
            action = env.action_space.sample()
            next_state, reward, term, trunc, _ = env.step(action)
            done = term or trunc
            
            # Only collect if action was 0
            if action == EXPANDED_ACTION:
                collector.add(state, next_state)
                total_action0_transitions += 1
            
            state = next_state
    
    env.close()
    
    print(f"Collected {total_action0_transitions} transitions for action 0")
    print(f"From {num_episodes} episodes")
    
    if save_path:
        import pickle
        with open(save_path, 'wb') as f:
            pickle.dump(list(collector.buffer), f)
        print(f"Saved to {save_path}")
    
    return collector


def train_transition_model(data_collector=None, epochs=100, batch_size=128, 
                           collect_episodes=200, save_path="transition_model_action0.pth"):
    """
    Train the transition model for action 0.
    
    Args:
        data_collector: Pre-collected data, or None to collect new data
        epochs: Number of training epochs
        batch_size: Batch size for training
        collect_episodes: Episodes to collect if data_collector is None
        save_path: Path to save trained model
        
    Returns:
        trainer: Trained TransitionModelTrainer
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Create model
    model = TransitionModelAction0(state_dim=8, hidden_dim=128, with_variance=True)
    trainer = TransitionModelTrainer(model, lr=1e-3, device=device)
    
    # Collect data if not provided
    if data_collector is None:
        print(f"\nCollecting data from {collect_episodes} episodes...")
        data_collector = collect_action0_data(num_episodes=collect_episodes)
    
    # Transfer data to trainer
    trainer.data_collector = data_collector
    
    print(f"\nTraining on {len(data_collector)} transitions...")
    print(f"Epochs: {epochs}, Batch size: {batch_size}")
    
    # Training loop
    all_losses = []
    for epoch in range(epochs):
        losses = trainer.train_epochs(epochs=10, batch_size=batch_size)
        avg_loss = np.mean(losses) if losses else 0
        all_losses.append(avg_loss)
        
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
    
    # Save model
    trainer.save(save_path)
    print(f"\nModel saved to {save_path}")
    
    # Test prediction
    print("\n--- Testing Predictions ---")
    env = gym.make("LunarLander-v3")
    test_errors = []
    
    for _ in range(10):
        state, _ = env.reset()
        # Take action 0
        next_state_true, _, _, _, _ = env.step(0)
        
        # Predict
        next_state_pred, confidence = trainer.model.predict(state)
        
        # Error
        error = np.mean((next_state_true - next_state_pred)**2)
        test_errors.append(error)
        
    env.close()
    
    print(f"Average prediction MSE: {np.mean(test_errors):.6f}")
    print(f"Std prediction MSE: {np.std(test_errors):.6f}")
    
    return trainer, all_losses


# =============================================================================
# Example usage and testing
# =============================================================================

def train_with_validation(collect_episodes=200, epochs=100, batch_size=128, 
                          val_split=0.2, save_path="transition_model_action0.pth",
                          patience=20, weight_decay=1e-4, dropout=0.2):
    """
    Train transition model with train/test split to check overfitting.
    
    Args:
        collect_episodes: Number of episodes to collect data from
        epochs: Maximum number of training epochs
        batch_size: Batch size for training
        val_split: Fraction of data for validation
        save_path: Path to save best model
        patience: Early stopping patience (stop if no improvement for N epochs)
        weight_decay: L2 regularization strength
        dropout: Dropout rate for regularization
    
    Returns:
        trainer: Trained model (best checkpoint)
        train_losses: Training loss per epoch
        test_losses: Testing loss per epoch
        train_mse: Training MSE (accuracy) per epoch
        test_mse: Testing MSE (accuracy) per epoch
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    print(f"\n--- Regularization Settings ---")
    print(f"Dropout: {dropout}")
    print(f"Weight Decay: {weight_decay}")
    print(f"Early Stopping Patience: {patience}")
    
    # Collect data
    print(f"\nCollecting data from {collect_episodes} episodes...")
    env = gym.make("LunarLander-v3")
    
    all_transitions = []
    for ep in range(collect_episodes):
        state, _ = env.reset()
        done = False
        while not done:
            action = env.action_space.sample()
            next_state, _, term, trunc, _ = env.step(action)
            done = term or trunc
            if action == 0:
                all_transitions.append((state.copy(), next_state.copy()))
            state = next_state
    env.close()
    
    print(f"Collected {len(all_transitions)} transitions for action 0")
    
    # Shuffle and split data
    np.random.shuffle(all_transitions)
    split_idx = int(len(all_transitions) * (1 - val_split))
    train_data = all_transitions[:split_idx]
    test_data = all_transitions[split_idx:]
    
    print(f"Training samples: {len(train_data)}")
    print(f"Testing samples: {len(test_data)}")
    
    # Prepare tensors
    train_states = torch.FloatTensor(np.array([t[0] for t in train_data])).to(device)
    train_next = torch.FloatTensor(np.array([t[1] for t in train_data])).to(device)
    test_states = torch.FloatTensor(np.array([t[0] for t in test_data])).to(device)
    test_next = torch.FloatTensor(np.array([t[1] for t in test_data])).to(device)
    
    # Create model with dropout
    model = TransitionModelAction0(state_dim=8, hidden_dim=128, with_variance=True, dropout=dropout).to(device)
    
    # Optimizer with weight decay (L2 regularization)
    optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=weight_decay)
    
    train_losses = []
    test_losses = []
    train_mse = []
    test_mse = []
    
    # Early stopping variables
    best_test_mse = float('inf')
    best_epoch = 0
    best_model_state = None
    epochs_without_improvement = 0
    
    print(f"\nTraining for up to {epochs} epochs (early stopping enabled)...")
    
    for epoch in range(epochs):
        # ============ Training ============
        model.train()
        
        # Shuffle training data
        perm = torch.randperm(len(train_states))
        epoch_train_loss = 0
        epoch_train_mse = 0
        n_batches = 0
        
        for i in range(0, len(train_states), batch_size):
            idx = perm[i:i+batch_size]
            batch_s = train_states[idx]
            batch_ns = train_next[idx]
            
            mean, logvar = model(batch_s)
            loss = 0.5 * (logvar + (batch_ns - mean)**2 * torch.exp(-logvar)).mean()
            
            # Calculate MSE (prediction accuracy)
            mse = ((batch_ns - mean)**2).mean()
            
            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            
            epoch_train_loss += loss.item()
            epoch_train_mse += mse.item()
            n_batches += 1
        
        avg_train_loss = epoch_train_loss / n_batches
        avg_train_mse = epoch_train_mse / n_batches
        train_losses.append(avg_train_loss)
        train_mse.append(avg_train_mse)
        
        # ============ Testing ============
        model.eval()
        with torch.no_grad():
            mean, logvar = model(test_states)
            test_loss = 0.5 * (logvar + (test_next - mean)**2 * torch.exp(-logvar)).mean()
            test_mse_val = ((test_next - mean)**2).mean()
            test_losses.append(test_loss.item())
            test_mse.append(test_mse_val.item())
        
        # ============ Early Stopping Check ============
        if test_mse_val.item() < best_test_mse:
            best_test_mse = test_mse_val.item()
            best_epoch = epoch + 1
            best_model_state = model.state_dict().copy()
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1
        
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1:3d}/{epochs} | Train Loss: {avg_train_loss:.4f} | Test Loss: {test_loss.item():.4f} | "
                  f"Train MSE: {avg_train_mse:.6f} | Test MSE: {test_mse_val.item():.6f} | "
                  f"No improvement: {epochs_without_improvement}")
        
        # Early stopping
        if epochs_without_improvement >= patience:
            print(f"\n*** Early stopping at epoch {epoch+1} (no improvement for {patience} epochs) ***")
            break
    
    # Load best model
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        print(f"\nLoaded best model from epoch {best_epoch} (Test MSE: {best_test_mse:.6f})")
    
    # Save best model
    torch.save(model.state_dict(), save_path)
    print(f"Model saved to {save_path}")
    
    # Create trainer object for compatibility
    trainer = TransitionModelTrainer(model, device=device)
    
    return trainer, train_losses, test_losses, train_mse, test_mse, best_epoch


def plot_overfitting_check(train_losses, test_losses, train_mse, test_mse, best_epoch=None, save_path='transition_model_overfitting.png'):
    """
    Plot training vs testing loss and MSE to check for overfitting.
    """
    import matplotlib.pyplot as plt
    
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    
    epochs = range(1, len(train_losses) + 1)
    
    # ============ Plot 1: Loss Curves (Normal Scale) ============
    ax1 = axes[0, 0]
    ax1.plot(epochs, train_losses, 'b-', linewidth=2, label='Training Loss')
    ax1.plot(epochs, test_losses, 'r-', linewidth=2, label='Testing Loss')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Loss (NLL)', fontsize=12)
    ax1.set_title('Training vs Testing Loss', fontsize=14, fontweight='bold')
    ax1.legend(fontsize=11)
    ax1.grid(alpha=0.3)
    
    # Mark best epoch
    if best_epoch:
        ax1.axvline(best_epoch, color='green', linestyle='--', alpha=0.7, linewidth=2, label=f'Best Epoch: {best_epoch}')
        ax1.legend(fontsize=10)
    
    # ============ Plot 2: Loss Curves (Log Scale) ============
    ax2 = axes[0, 1]
    min_loss = min(min(train_losses), min(test_losses))
    if min_loss < 0:
        shift = abs(min_loss) + 1
        train_losses_shifted = [l + shift for l in train_losses]
        test_losses_shifted = [l + shift for l in test_losses]
        ax2.plot(epochs, train_losses_shifted, 'b-', linewidth=2, label='Training Loss (shifted)')
        ax2.plot(epochs, test_losses_shifted, 'r-', linewidth=2, label='Testing Loss (shifted)')
        ax2.set_ylabel(f'Loss + {shift:.1f} (Log Scale)', fontsize=12)
    else:
        ax2.plot(epochs, train_losses, 'b-', linewidth=2, label='Training Loss')
        ax2.plot(epochs, test_losses, 'r-', linewidth=2, label='Testing Loss')
        ax2.set_ylabel('Loss (Log Scale)', fontsize=12)
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_title('Training vs Testing Loss (Log Scale)', fontsize=14, fontweight='bold')
    ax2.set_yscale('log')
    ax2.legend(fontsize=11)
    ax2.grid(alpha=0.3)
    
    # ============ Plot 3: MSE Curves (Accuracy) ============
    ax3 = axes[1, 0]
    ax3.plot(epochs, train_mse, 'b-', linewidth=2, label='Training MSE')
    ax3.plot(epochs, test_mse, 'r-', linewidth=2, label='Testing MSE')
    ax3.set_xlabel('Epoch', fontsize=12)
    ax3.set_ylabel('MSE (Mean Squared Error)', fontsize=12)
    ax3.set_title('Training vs Testing MSE (Prediction Accuracy)', fontsize=14, fontweight='bold')
    ax3.legend(fontsize=11)
    ax3.grid(alpha=0.3)
    
    # Mark best epoch
    if best_epoch and best_epoch <= len(test_mse):
        best_test_mse = test_mse[best_epoch - 1]
        ax3.axvline(best_epoch, color='green', linestyle='--', alpha=0.7, linewidth=2)
        ax3.scatter([best_epoch], [best_test_mse], color='green', s=100, zorder=5, label=f'Best: Epoch {best_epoch}')
        ax3.legend(fontsize=10)
    
    # ============ Plot 4: MSE Curves (Log Scale) ============
    ax4 = axes[1, 1]
    ax4.plot(epochs, train_mse, 'b-', linewidth=2, label='Training MSE')
    ax4.plot(epochs, test_mse, 'r-', linewidth=2, label='Testing MSE')
    ax4.set_xlabel('Epoch', fontsize=12)
    ax4.set_ylabel('MSE (Log Scale)', fontsize=12)
    ax4.set_title('Training vs Testing MSE (Log Scale)', fontsize=14, fontweight='bold')
    ax4.set_yscale('log')
    ax4.legend(fontsize=11)
    ax4.grid(alpha=0.3)
    
    if best_epoch:
        ax4.axvline(best_epoch, color='green', linestyle='--', alpha=0.7, linewidth=2)
    
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    plt.show()
    
    # Print summary
    best_mse_epoch = np.argmin(test_mse) + 1
    best_test_mse_val = min(test_mse)
    
    print("\n" + "="*60)
    print("OVERFITTING CHECK SUMMARY")
    print("="*60)
    print(f"\n--- Loss (NLL) ---")
    print(f"Final Training Loss: {train_losses[-1]:.6f}")
    print(f"Final Testing Loss:  {test_losses[-1]:.6f}")
    
    print(f"\n--- MSE (Prediction Accuracy) ---")
    print(f"Final Training MSE:  {train_mse[-1]:.6f}")
    print(f"Final Testing MSE:   {test_mse[-1]:.6f}")
    print(f"Best Testing MSE:    {best_test_mse_val:.6f} (Epoch {best_mse_epoch})")
    print(f"Final RMSE:          {np.sqrt(test_mse[-1]):.6f}")
    
    if best_epoch:
        print(f"\n--- Early Stopping ---")
        print(f"Best model saved at: Epoch {best_epoch}")
    
    # Overfitting check
    mse_gap = test_mse[-1] - train_mse[-1]
    print(f"\n--- Overfitting Analysis ---")
    print(f"MSE Gap (Test - Train): {mse_gap:.6f}")
    
    if mse_gap > train_mse[-1] * 0.5:
        print("\n⚠️  WARNING: Possible overfitting detected!")
        print("   Test MSE is significantly higher than train MSE.")
    elif len(test_mse) > 10 and test_mse[-1] > test_mse[len(test_mse)//2] * 1.1:
        print("\n⚠️  WARNING: Test MSE increasing - overfitting!")
    else:
        print("\n✅ Model generalizes well!")
        if mse_gap < 0:
            print("   Test MSE is actually better than train MSE.")
    print("="*60)


if __name__ == "__main__":
    import matplotlib.pyplot as plt
    
    print("="*60)
    print("TRANSITION MODEL FOR ACTION 0 (NOOP)")
    print("With Early Stopping and Regularization")
    print("="*60)
    
    # Train with validation, early stopping, and regularization
    trainer, train_losses, test_losses, train_mse, test_mse, best_epoch = train_with_validation(
        collect_episodes=200,
        epochs=100,
        batch_size=128,
        val_split=0.2,
        patience=20,           # Early stopping: stop if no improvement for 20 epochs
        weight_decay=1e-4,     # L2 regularization
        dropout=0.2,           # Dropout regularization
        save_path="transition_model_action0.pth"
    )
    
    # Plot overfitting check
    plot_overfitting_check(train_losses, test_losses, train_mse, test_mse, 
                           best_epoch=best_epoch,
                           save_path='transition_model_overfitting.png')
    
    print("\nResults saved to 'transition_model_overfitting.png'")
# Out:
# ============================================================
# TRANSITION MODEL FOR ACTION 0 (NOOP)
# With Early Stopping and Regularization
# ============================================================
# Using device: cpu
#
# --- Regularization Settings ---
# Dropout: 0.2
# Weight Decay: 0.0001
# Early Stopping Patience: 20
#
# Collecting data from 200 episodes...
# Collected 4746 transitions for action 0
# Training samples: 3796
# Testing samples: 950
#
# Training for up to 100 epochs (early stopping enabled)...
# Epoch  10/100 | Train Loss: -1.8229 | Test Loss: -2.1209 | Train MSE: 0.048053 | Test MSE: 0.031718 | No improvement: 1
# Epoch  20/100 | Train Loss: -1.8553 | Test Loss: -2.2044 | Train MSE: 0.047729 | Test MSE: 0.030818 | No improvement: 0
# Epoch  30/100 | Train Loss: -1.9119 | Test Loss: -2.2514 | Train MSE: 0.047024 | Test MSE: 0.031879 | No improvement: 10
# Epoch  40/100 | Train Loss: -1.9101 | Test Loss: -2.1643 | Train MSE: 0.046272 | Test MSE: 0.032216 | No improvement: 20
#
# *** Early stopping at epoch 40 (no improvement for 20 epochs) ***
#
# Loaded best model from epoch 20 (Test MSE: 0.030818)
# Model saved to transition_model_action0.pth
# ============================================================
# OVERFITTING CHECK SUMMARY
# ============================================================
#
# --- Loss (NLL) ---
# Final Training Loss: -1.910058
# Final Testing Loss:  -2.164302
#
# --- MSE (Prediction Accuracy) ---
# Final Training MSE:  0.046272
# Final Testing MSE:   0.032216
# Best Testing MSE:    0.030818 (Epoch 20)
# Final RMSE:          0.179488
#
# --- Early Stopping ---
# Best model saved at: Epoch 20
#
# --- Overfitting Analysis ---
# MSE Gap (Test - Train): -0.014056
#
# ✅ Model generalizes well!
#    Test MSE is actually better than train MSE.
# ============================================================
#
# Results saved to 'transition_model_overfitting.png'

# %% [markdown]
# ### Using the model to predict the transition of action zero

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
transition_model = TransitionModelAction0(state_dim=8, hidden_dim=128, with_variance=True).to(device)
transition_model.load_state_dict(torch.load("transition_model_action0.pth", map_location=device))
transition_model.eval()
# Out:
# /var/folders/7y/tb8vlfv937523rgqdlf0zjy40000gn/T/ipykernel_50144/3382922215.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   transition_model.load_state_dict(torch.load("transition_model_action0.pth", map_location=device))
# TransitionModelAction0(
#   (fc1): Linear(in_features=8, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=128, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc_mean): Linear(in_features=128, out_features=8, bias=True)
#   (fc_logvar): Linear(in_features=128, out_features=8, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# ### Adaptive Agent

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class ActionExplorer(nn.Module): 
    def __init__(self, state_dim, action_dim, full_action: ActionMap, hidden_dim=64, learning_rate=0.001):
        super().__init__()
        
        self.model = nn.Sequential(
            nn.Linear(state_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, action_dim)
        )
        self.optimizer = optim.Adam(self.model.parameters(), lr=learning_rate)
        ouput_layer = self.model[-1]
        
        with torch.no_grad():
            for i in full_action.get_expand_actions_in_network():
                ouput_layer.weight[i] *= 0.01
                ouput_layer.bias[i] = -50 #large NEGATIVE values (makes logits small → low probability)
        
    def forward(self, state):
        logits = self.model(state)
        probs = torch.softmax(logits, dim=-1) 
        return probs
    
    def get_action_frequencies(self, state):
        with torch.no_grad():
            probs = self.forward(state)
        return probs.cpu().numpy()
    
    def get_least_tried_action(self, state):
        freqs = self.get_action_frequencies(state)
        least_tried_action = freqs.argmin()
        return least_tried_action
    
    def update(self, state, action):
        probs = self.forward(state)
        loss = -torch.log(probs[action] + 1e-10)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item() 
    
class AdaptiveAgent():
    def __init__(self, n_observations, base_action_map: ActionMap,
                 full_action_map: ActionMap, base_agent_path = BASE_MODEL_PATH,
                 uncertainty_threshold=0.5, batch_size=128, gamma=0.99, lr=1e-4, tau=0.005):
        self.base_agent = base_agent_path
        self.base_action_map = base_action_map
        self.full_action_map = full_action_map
        self.uncertainty_threshold = uncertainty_threshold
        self.batch_size = batch_size
        self.episode_duration = []
        self.reward_list = []
        self.action_selected = []
        
        self.action_explorer = ActionExplorer(state_dim=n_observations,
                                              action_dim=len(full_action_map.action_map),
                                              full_action=full_action_map,
                                              hidden_dim=64,
                                              ).to(device)
        self.base_q_net = DQN(n_observations= n_observations, n_actions=len(base_action_map.action_map)).to(device)
        self.base_q_net.load_state_dict(torch.load(base_agent_path, map_location=device, weights_only=True))
        self.base_q_net.eval()
        for param in self.base_q_net.parameters():
            param.requires_grad = False
        
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.policy_net = DQN(n_observations= n_observations, n_actions=len(full_action_map.action_map)).to(self.device)
        self.target_net = DQN(n_observations= n_observations, n_actions=len(full_action_map.action_map)).to(self.device)
        self.replay_memory = ReplayMemory(10000)
        # fine-tune model
        pretrained_dict = torch.load(base_agent_path, map_location=self.device, weights_only=True)
        new_model_dict = self.policy_net.state_dict()
        
        self.GAMMA = gamma
        self.LR = lr
        self.TAU = tau
        self.EPSILON = 1.0
        self.EPSILON_MIN = 0.01
        self.EPSILON_DECAY = 0.995
        self.allow_expansion = 0
        self.reject_expansion = 0
        # transfer weights
        for name, param in pretrained_dict.items():    
            if name in new_model_dict:
                if 'layer3' in name:
                    if 'weight' in name:
                        old_weight = param.clone()
                        new_weight = new_model_dict[name].clone()
                        size_base_action = len(base_action_map.select_all_actions_in_env())
                        size_full_action = len(full_action_map.select_all_actions_in_env())
                        new_weight[:size_base_action] = old_weight
                         
                         # copy random weights for new actions
                        for i in range(size_base_action, size_full_action):
                            new_weight[i] = old_weight[np.random.randint(0, size_base_action)].clone()
                        new_model_dict[name] = new_weight
                    elif 'bias' in name:
                        old_bias = param.clone()
                        new_bias = new_model_dict[name].clone()
                        size_base_action = len(base_action_map.select_all_actions_in_env())
                        size_full_action = len(full_action_map.select_all_actions_in_env())
                        new_bias[:size_base_action] = old_bias
                        
                        # copy random biases for new actions
                        for i in range(size_base_action, size_full_action):
                            new_bias[i] = old_bias[np.random.randint(0, size_base_action)].clone()
                        new_model_dict[name] = new_bias
                else:# copy other layers directly
                    new_model_dict[name] = param
        self.policy_net.load_state_dict(new_model_dict)
        self.target_net.load_state_dict(self.policy_net.state_dict())  
        self.optimizer = optim.AdamW(self.policy_net.parameters(), lr=self.LR)
        self.criterion = nn.SmoothL1Loss()    
                 
    def select_action(self, state, epsilon, select_old_action: False):
        selected_action = None
        if np.random.rand() < epsilon:
            if select_old_action:
                action = np.random.choice(self.base_action_map.select_all_actions_in_network())
                selected_action = torch.tensor([[action]], dtype=torch.long, device=self.device)
                return selected_action
            # else:
            #     action = self.action_explorer.get_least_tried_action(state.squeeze(0))
            #     selected_action = torch.tensor([[action]], dtype=torch.long, device=self.device)
            # was_exploration = True
        else:
            with torch.no_grad():
                q_values = self.policy_net(state) # 5 actions [1,2,3,4, 4]
                # random.choice(4,5)
                #  [1,2,4,2, 4]
                # random.choice(3, 5)
                # add decay to exploration new actions
                selected_action = self.policy_net(state).max(1).indices.view(1, 1)
            action = selected_action.item()
            self.action_explorer.update(state.squeeze(0), action)
            was_exploration = False
        return selected_action
    
    def train(self, env, num_episodes, train_transition_model):
       
        for episode in range(num_episodes):
            total_reward = 0
            state, _ = env.reset()
            episode_action = [0] * len(self.full_action_map.action_map)
            state = torch.tensor(
                state, dtype=torch.float32, device=self.device
            ).unsqueeze(0)
            
            for t in count(): 
                # max (1,2,3)
                action_network = self.select_action(state, self.EPSILON, select_old_action= False)
            
                env_action = self.full_action_map.convert_network_action_to_env(action_network.item())
                episode_action[env_action] += 1
                if action_network.item() in self.full_action_map.get_expand_actions_in_network():
                    # Use transition model to predict next state 
                    predicted_next_state, _ = train_transition_model.predict(state.cpu().squeeze(0).numpy())
                    q_value_current_state = self.base_q_net(state).max(1).values.item()
                    q_value_next_state = self.base_q_net(torch.tensor(predicted_next_state, dtype=torch.float32, device=self.device).unsqueeze(0)).max(1).values.item()
                    if q_value_next_state >= q_value_current_state:
                        self.allow_expansion += 1
                    else:
                        self.reject_expansion += 1
                        action_network = self.select_action(state, self.EPSILON, select_old_action= True)
                        env_action = self.full_action_map.convert_network_action_to_env(action_network.item())
                self.action_explorer.update(state.squeeze(0), action_network.item())    
                next_state, reward, terminated, truncated, _ = env.step(env_action)
                done = terminated or truncated
                reward = torch.tensor([reward], device=self.device)
                next_state = torch.tensor(
                    next_state, dtype=torch.float32, device=self.device
                ).unsqueeze(0)
                self.replay_memory.push(state, action_network, next_state, reward, done)
                state = next_state
                total_reward += reward.item()
                if len(self.replay_memory) >= self.batch_size:
                    transitions = self.replay_memory.sample(self.batch_size)
                    states, actions, next_states, rewards, dones = zip(*transitions) 
                    #convert tuple to tensor array
                    states_batch = torch.cat(states) # states is a tuple, now it becomes a batch (2D array)
                    next_states_batch = torch.cat(next_states)
                    actions_batch = torch.cat(actions)
                    
                    reward_batch = torch.tensor(rewards, device= self.device)
                    dones_batch = torch.tensor(dones, dtype=torch.float32, device=self.device)
                    
                    # Q-value which are estimating (policy network)
                    q_values = self.policy_net(states_batch).gather(1, actions_batch).squeeze()
                    
                    # get target Q-values
                    with torch.no_grad():
                        next_q_values = self.target_net(next_states_batch).max(1).values
                        target_q_values = reward_batch + self.GAMMA * next_q_values * (1 - dones_batch)
                    loss = self.criterion(q_values, target_q_values) # prove converge
                    
                    self.optimizer.zero_grad()
                    loss.backward()
                    torch.nn.utils.clip_grad_norm_(self.policy_net.parameters(), 1.0)
                    self.optimizer.step()
                    
                    # soft update target network
                    for target_param, policy_param in zip(self.target_net.parameters(), self.policy_net.parameters()):
                        target_param.data.copy_(self.TAU * policy_param.data + (1 - self.TAU) * target_param.data)
                if done:
                    self.episode_duration.append(t+1)
                    self.action_selected.append(episode_action)
                    break
            # Decay epsilon    
            self.EPSILON = max(self.EPSILON_MIN, self.EPSILON * self.EPSILON_DECAY)
            self.reward_list.append(total_reward)
            
            if (episode + 1) % 10 == 0:
                avg_reward = np.mean(self.reward_list[-10:])
                print(f"Episode {episode+1}/{num_episodes}, Reward: {total_reward:.2f}, "
                    f"Avg10: {avg_reward:.2f}, Epsilon: {self.EPSILON:.3f}")

# %% [markdown]
# ### Train adaptive model

# %%
env = gym.make("LunarLander-v3")
agent = DDQNAgent(n_observation = env.observation_space.shape[0], action_data = base_action_map)
agent.train(env, num_episodes= NUMBER_OF_EPISODES)
reward_list = agent.reward_list
episode_durations = agent.episode_duration

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
transition_model = TransitionModelAction0(state_dim=8, hidden_dim=128, with_variance=True).to(device)
transition_model.load_state_dict(torch.load("transition_model_action0.pth", map_location=device))
transition_model.eval()

env = gym.make("LunarLander-v3")
n_observations = env.observation_space.shape[0]
adaptive_agent = AdaptiveAgent(n_observations=n_observations,
                               base_action_map=base_action_map, full_action_map=full_action_map,
                               base_agent_path=BASE_MODEL_PATH, uncertainty_threshold=0.5)

adaptive_agent.train(env, num_episodes=NUMBER_OF_EPISODES, train_transition_model= transition_model)

n_observations = env.observation_space.shape[0]
full_action_agent = DDQNAgent(n_observation = n_observations, action_data = full_action_map)
full_action_agent.train(env, NUMBER_OF_EPISODES)
# Out:
# Episode 10/500, Reward: -68.17, Avg10: -175.97, Epsilon: 0.951
# Episode 20/500, Reward: -49.12, Avg10: -134.65, Epsilon: 0.905
# Episode 30/500, Reward: -363.32, Avg10: -187.47, Epsilon: 0.860
# Episode 40/500, Reward: -92.67, Avg10: -146.93, Epsilon: 0.818
# Episode 50/500, Reward: -177.10, Avg10: -85.01, Epsilon: 0.778
# Episode 60/500, Reward: -243.25, Avg10: -84.44, Epsilon: 0.740
# Episode 70/500, Reward: -53.21, Avg10: -83.41, Epsilon: 0.704
# Episode 80/500, Reward: -84.71, Avg10: -59.30, Epsilon: 0.670
# Episode 90/500, Reward: -51.90, Avg10: -82.13, Epsilon: 0.637
# Episode 100/500, Reward: -54.83, Avg10: -75.82, Epsilon: 0.606
# Episode 110/500, Reward: -37.73, Avg10: -65.52, Epsilon: 0.576
# Episode 120/500, Reward: -32.26, Avg10: -57.37, Epsilon: 0.548
# Episode 130/500, Reward: 1.30, Avg10: -25.33, Epsilon: 0.521
# Episode 140/500, Reward: -36.15, Avg10: -28.32, Epsilon: 0.496
# Episode 150/500, Reward: -80.69, Avg10: -68.44, Epsilon: 0.471
# Episode 160/500, Reward: -2.03, Avg10: -31.40, Epsilon: 0.448
# Episode 170/500, Reward: 41.40, Avg10: -10.06, Epsilon: 0.427
# Episode 180/500, Reward: 37.68, Avg10: 1.16, Epsilon: 0.406
# Episode 190/500, Reward: 17.00, Avg10: 1.94, Epsilon: 0.386
# Episode 200/500, Reward: 104.56, Avg10: 52.57, Epsilon: 0.367
# Episode 210/500, Reward: 63.31, Avg10: 40.70, Epsilon: 0.349
# Episode 220/500, Reward: -20.09, Avg10: 59.27, Epsilon: 0.332
# Episode 230/500, Reward: 13.36, Avg10: 33.72, Epsilon: 0.316
# Episode 240/500, Reward: 79.17, Avg10: 59.05, Epsilon: 0.300
# Episode 250/500, Reward: 44.56, Avg10: 61.01, Epsilon: 0.286
# Episode 260/500, Reward: 240.32, Avg10: 74.41, Epsilon: 0.272
# Episode 270/500, Reward: 85.30, Avg10: 86.24, Epsilon: 0.258
# Episode 280/500, Reward: 32.45, Avg10: -4.09, Epsilon: 0.246
# Episode 290/500, Reward: -217.22, Avg10: 71.57, Epsilon: 0.234
# Episode 300/500, Reward: 75.20, Avg10: 83.48, Epsilon: 0.222
# Episode 310/500, Reward: 189.56, Avg10: 138.61, Epsilon: 0.211
# Episode 320/500, Reward: 28.41, Avg10: 86.09, Epsilon: 0.201
# Episode 330/500, Reward: 251.10, Avg10: 163.84, Epsilon: 0.191
# Episode 340/500, Reward: 223.46, Avg10: 97.81, Epsilon: 0.182
# Episode 350/500, Reward: -19.70, Avg10: 114.27, Epsilon: 0.173
# Episode 360/500, Reward: 100.09, Avg10: 98.88, Epsilon: 0.165
# Episode 370/500, Reward: 146.97, Avg10: 119.00, Epsilon: 0.157
# Episode 380/500, Reward: 115.25, Avg10: 119.31, Epsilon: 0.149
# Episode 390/500, Reward: 116.54, Avg10: 140.31, Epsilon: 0.142
# Episode 400/500, Reward: 25.69, Avg10: 117.64, Epsilon: 0.135
# Episode 410/500, Reward: 140.49, Avg10: 97.99, Epsilon: 0.128
# Episode 420/500, Reward: 225.43, Avg10: 145.72, Epsilon: 0.122
# Episode 430/500, Reward: 114.27, Avg10: 132.16, Epsilon: 0.116
# Episode 440/500, Reward: 13.16, Avg10: 95.01, Epsilon: 0.110
# Episode 450/500, Reward: 64.09, Avg10: 77.93, Epsilon: 0.105
# Episode 460/500, Reward: 97.87, Avg10: 105.02, Epsilon: 0.100
# Episode 470/500, Reward: 125.21, Avg10: 122.07, Epsilon: 0.095
# Episode 480/500, Reward: 98.21, Avg10: 113.35, Epsilon: 0.090
# Episode 490/500, Reward: 73.04, Avg10: 97.45, Epsilon: 0.086
# Episode 500/500, Reward: 109.09, Avg10: 48.19, Epsilon: 0.082
# /var/folders/7y/tb8vlfv937523rgqdlf0zjy40000gn/T/ipykernel_50144/857338020.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   transition_model.load_state_dict(torch.load("transition_model_action0.pth", map_location=device))
# Episode 10/500, Reward: -292.61, Avg10: -302.65, Epsilon: 0.951
# Episode 20/500, Reward: -161.19, Avg10: -274.73, Epsilon: 0.905
# Episode 30/500, Reward: -287.39, Avg10: -250.38, Epsilon: 0.860
# Episode 40/500, Reward: -139.56, Avg10: -144.16, Epsilon: 0.818
# Episode 50/500, Reward: -35.74, Avg10: -133.92, Epsilon: 0.778
# Episode 60/500, Reward: -62.63, Avg10: -130.73, Epsilon: 0.740
# Episode 70/500, Reward: -118.17, Avg10: -118.31, Epsilon: 0.704
# Episode 80/500, Reward: -94.97, Avg10: -122.24, Epsilon: 0.670
# Episode 90/500, Reward: -123.95, Avg10: -84.35, Epsilon: 0.637
# Episode 100/500, Reward: -104.76, Avg10: -73.65, Epsilon: 0.606
# Episode 110/500, Reward: -40.92, Avg10: -76.81, Epsilon: 0.576
# Episode 120/500, Reward: -59.21, Avg10: -17.17, Epsilon: 0.548
# Episode 130/500, Reward: -58.36, Avg10: -49.56, Epsilon: 0.521
# Episode 140/500, Reward: -17.83, Avg10: -30.05, Epsilon: 0.496
# Episode 150/500, Reward: -67.81, Avg10: -40.69, Epsilon: 0.471
# Episode 160/500, Reward: -26.59, Avg10: -26.97, Epsilon: 0.448
# Episode 170/500, Reward: -6.45, Avg10: -41.67, Epsilon: 0.427
# Episode 180/500, Reward: -15.01, Avg10: -49.93, Epsilon: 0.406
# Episode 190/500, Reward: 32.30, Avg10: -7.56, Epsilon: 0.386
# Episode 200/500, Reward: 14.08, Avg10: 1.10, Epsilon: 0.367
# Episode 210/500, Reward: -58.80, Avg10: 2.19, Epsilon: 0.349
# Episode 220/500, Reward: 35.50, Avg10: 63.34, Epsilon: 0.332
# Episode 230/500, Reward: 30.24, Avg10: 130.04, Epsilon: 0.316
# Episode 240/500, Reward: 23.60, Avg10: 110.51, Epsilon: 0.300
# Episode 250/500, Reward: 226.73, Avg10: 100.13, Epsilon: 0.286
# Episode 260/500, Reward: 258.24, Avg10: 174.96, Epsilon: 0.272
# Episode 270/500, Reward: 21.58, Avg10: 139.73, Epsilon: 0.258
# Episode 280/500, Reward: 266.58, Avg10: 129.71, Epsilon: 0.246
# Episode 290/500, Reward: 6.32, Avg10: 166.27, Epsilon: 0.234
# Episode 300/500, Reward: 266.93, Avg10: 150.34, Epsilon: 0.222
# Episode 310/500, Reward: 246.72, Avg10: 212.13, Epsilon: 0.211
# Episode 320/500, Reward: 250.11, Avg10: 183.62, Epsilon: 0.201
# Episode 330/500, Reward: 288.63, Avg10: 221.34, Epsilon: 0.191
# Episode 340/500, Reward: -0.43, Avg10: 203.43, Epsilon: 0.182
# Episode 350/500, Reward: 198.98, Avg10: 218.87, Epsilon: 0.173
# Episode 360/500, Reward: 131.14, Avg10: 219.04, Epsilon: 0.165
# Episode 370/500, Reward: 3.44, Avg10: 181.07, Epsilon: 0.157
# Episode 380/500, Reward: 227.32, Avg10: 231.95, Epsilon: 0.149
# Episode 390/500, Reward: 266.62, Avg10: 187.22, Epsilon: 0.142
# Episode 400/500, Reward: 15.74, Avg10: 131.88, Epsilon: 0.135
# Episode 410/500, Reward: 245.91, Avg10: 129.25, Epsilon: 0.128
# Episode 420/500, Reward: 277.59, Avg10: 210.58, Epsilon: 0.122
# Episode 430/500, Reward: 292.80, Avg10: 222.73, Epsilon: 0.116
# Episode 440/500, Reward: 267.97, Avg10: 212.95, Epsilon: 0.110
# Episode 450/500, Reward: 12.65, Avg10: 146.13, Epsilon: 0.105
# Episode 460/500, Reward: 4.09, Avg10: 190.69, Epsilon: 0.100
# Episode 470/500, Reward: 264.33, Avg10: 187.07, Epsilon: 0.095
# Episode 480/500, Reward: 241.74, Avg10: 176.07, Epsilon: 0.090
# Episode 490/500, Reward: 257.86, Avg10: 143.80, Epsilon: 0.086
# Episode 500/500, Reward: 247.96, Avg10: 200.81, Epsilon: 0.082
# Episode 10/500, Reward: -89.15, Avg10: -139.93, Epsilon: 0.951
# Episode 20/500, Reward: -143.96, Avg10: -155.20, Epsilon: 0.905
# Episode 420/500, Reward: 58.03, Avg10: 155.00, Epsilon: 0.122
# Episode 430/500, Reward: 12.39, Avg10: 211.34, Epsilon: 0.116
# Episode 440/500, Reward: 246.86, Avg10: 187.20, Epsilon: 0.110
# Episode 450/500, Reward: 291.48, Avg10: 219.09, Epsilon: 0.105
# Episode 460/500, Reward: 13.21, Avg10: 212.64, Epsilon: 0.100
# Episode 470/500, Reward: 250.10, Avg10: 219.28, Epsilon: 0.095
# Episode 480/500, Reward: 249.13, Avg10: 208.96, Epsilon: 0.090
# Episode 490/500, Reward: 272.21, Avg10: 172.81, Epsilon: 0.086
# Episode 500/500, Reward: 55.70, Avg10: 144.50, Epsilon: 0.082

# %%
import matplotlib.pyplot as plt

# Sum actions across all episodes
total_actions = [sum(ep[i] for ep in adaptive_agent.action_selected) 
                 for i in range(len(adaptive_agent.action_selected[0]))]

plt.figure(figsize=(10, 5))
plt.bar(range(len(total_actions)), total_actions, color='blue', alpha=0.7)
plt.xlabel('Action Index')
plt.ylabel('Total Selections')
plt.title('Total Action Selection Frequency by Adaptive Agent')
plt.xticks(range(len(total_actions)), [f'Action {i}' for i in range(len(total_actions))])
plt.grid(axis='y', alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

action_data = np.array(adaptive_agent.action_selected)  # Shape: (num_episodes, num_actions)
num_episodes = action_data.shape[0]
num_actions = action_data.shape[1]

plt.figure(figsize=(14, 6))
bottom = np.zeros(num_episodes)
colors = ['red', 'green', 'blue', 'orange']

for action_idx in range(num_actions):
    plt.bar(range(num_episodes), action_data[:, action_idx], bottom=bottom, 
            label=f'Action {action_idx}', color=colors[action_idx], alpha=0.7)
    bottom += action_data[:, action_idx]

plt.xlabel('Episode')
plt.ylabel('Action Count')
plt.title('Action Selection per Episode (Stacked)')
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ### Train full action from scratch

# %%
import random
import numpy as np
import torch

def set_seed(seed):
    """Set all random seeds for reproducibility."""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Store results for each seed
SEEDS = [42, 123, 456, 789, 1024]
#SEEDS = [42]
all_results = {
    'base': {'rewards': [], 'durations': []},
    'adaptive': {'rewards': [], 'durations': [], 'actions': []},
    'full': {'rewards': [], 'durations': []}
}

for seed in SEEDS:
    print(f"\n{'='*60}")
    print(f"RUNNING SEED {seed}")
    print(f"{'='*60}")
    
    set_seed(seed)
    
    # Train Base Agent (3 actions)
    env = gym.make("LunarLander-v3")
    env.reset(seed=seed)
    agent = DDQNAgent(n_observation=env.observation_space.shape[0], action_data=base_action_map)
    agent.train(env, num_episodes=NUMBER_OF_EPISODES)
    all_results['base']['rewards'].append(agent.reward_list)
    all_results['base']['durations'].append(agent.episode_duration)
    env.close()
    
    # Train Adaptive Agent
    set_seed(seed)
    env = gym.make("LunarLander-v3")
    env.reset(seed=seed)
    n_observations = env.observation_space.shape[0]
    adaptive_agent = AdaptiveAgent(n_observations=n_observations,
                                   base_action_map=base_action_map, 
                                   full_action_map=full_action_map,
                                   base_agent_path=BASE_MODEL_PATH)
    adaptive_agent.train(env, num_episodes=NUMBER_OF_EPISODES, train_transition_model=transition_model)
    all_results['adaptive']['rewards'].append(adaptive_agent.reward_list)
    all_results['adaptive']['durations'].append(adaptive_agent.episode_duration)
    all_results['adaptive']['actions'].append(adaptive_agent.action_selected)
    env.close()
    
    # Train Full Action Agent (from scratch)
    set_seed(seed)
    env = gym.make("LunarLander-v3")
    env.reset(seed=seed)
    full_action_agent = DDQNAgent(n_observation=n_observations, action_data=full_action_map)
    full_action_agent.train(env, NUMBER_OF_EPISODES)
    all_results['full']['rewards'].append(full_action_agent.reward_list)
    all_results['full']['durations'].append(full_action_agent.episode_duration)
    env.close()

print("\n" + "="*60)
print("ALL SEEDS COMPLETED!")
print("="*60)
# Out:
# ============================================================
# RUNNING SEED 42
# ============================================================
# Episode 10/600, Reward: -520.90, Avg10: -205.28, Epsilon: 0.951
# Episode 20/600, Reward: -103.68, Avg10: -241.97, Epsilon: 0.905
# Episode 30/600, Reward: -62.94, Avg10: -143.57, Epsilon: 0.860
# Episode 40/600, Reward: -107.92, Avg10: -149.38, Epsilon: 0.818
# Episode 50/600, Reward: -96.71, Avg10: -138.37, Epsilon: 0.778
# Episode 60/600, Reward: -29.95, Avg10: -77.87, Epsilon: 0.740
# Episode 70/600, Reward: -27.74, Avg10: -82.98, Epsilon: 0.704
# Episode 80/600, Reward: -212.14, Avg10: -82.97, Epsilon: 0.670
# Episode 90/600, Reward: -114.71, Avg10: -82.44, Epsilon: 0.637
# Episode 100/600, Reward: -27.99, Avg10: -58.16, Epsilon: 0.606
# Episode 110/600, Reward: -74.88, Avg10: -76.48, Epsilon: 0.576
# Episode 120/600, Reward: -51.40, Avg10: -50.35, Epsilon: 0.548
# Episode 130/600, Reward: 1.03, Avg10: -25.09, Epsilon: 0.521
# Episode 140/600, Reward: -185.05, Avg10: -55.93, Epsilon: 0.496
# Episode 150/600, Reward: 4.15, Avg10: -35.38, Epsilon: 0.471
# Episode 160/600, Reward: -40.48, Avg10: -19.89, Epsilon: 0.448
# Episode 170/600, Reward: 28.24, Avg10: 14.91, Epsilon: 0.427
# Episode 180/600, Reward: -17.88, Avg10: -6.30, Epsilon: 0.406
# Episode 190/600, Reward: 53.78, Avg10: 32.53, Epsilon: 0.386
# Episode 200/600, Reward: -38.75, Avg10: 1.46, Epsilon: 0.367
# Episode 210/600, Reward: -94.48, Avg10: -2.16, Epsilon: 0.349
# Episode 220/600, Reward: 31.88, Avg10: 2.46, Epsilon: 0.332
# Episode 230/600, Reward: 118.61, Avg10: 4.93, Epsilon: 0.316
# Episode 240/600, Reward: 69.25, Avg10: 48.34, Epsilon: 0.300
# Episode 250/600, Reward: 52.21, Avg10: 49.11, Epsilon: 0.286
# Episode 260/600, Reward: 87.31, Avg10: 79.32, Epsilon: 0.272
# Episode 270/600, Reward: 88.16, Avg10: 106.98, Epsilon: 0.258
# Episode 280/600, Reward: 64.31, Avg10: 88.57, Epsilon: 0.246
# Episode 290/600, Reward: 125.42, Avg10: 85.88, Epsilon: 0.234
# Episode 300/600, Reward: 0.50, Avg10: 101.60, Epsilon: 0.222
# Episode 310/600, Reward: 259.03, Avg10: 107.31, Epsilon: 0.211
# Episode 320/600, Reward: 142.03, Avg10: 84.78, Epsilon: 0.201
# Episode 300/600, Reward: 39.98, Avg10: 95.91, Epsilon: 0.222
# Episode 310/600, Reward: -136.39, Avg10: 78.70, Epsilon: 0.211
# Episode 320/600, Reward: 128.58, Avg10: 113.24, Epsilon: 0.201
# Episode 330/600, Reward: 247.97, Avg10: 102.15, Epsilon: 0.191
# Episode 340/600, Reward: 251.31, Avg10: 181.35, Epsilon: 0.182
# Episode 350/600, Reward: 71.77, Avg10: 217.53, Epsilon: 0.173
# Episode 360/600, Reward: 230.01, Avg10: 195.88, Epsilon: 0.165
# Episode 370/600, Reward: 245.98, Avg10: 228.32, Epsilon: 0.157
# Episode 380/600, Reward: 238.81, Avg10: 220.26, Epsilon: 0.149
# Episode 390/600, Reward: -9.21, Avg10: 84.17, Epsilon: 0.142
# Episode 400/600, Reward: 271.49, Avg10: 228.80, Epsilon: 0.135
# Episode 410/600, Reward: 269.01, Avg10: 135.22, Epsilon: 0.128
# Episode 420/600, Reward: 198.59, Avg10: 212.98, Epsilon: 0.122
# Episode 430/600, Reward: 258.55, Avg10: 228.90, Epsilon: 0.116
# Episode 440/600, Reward: 213.87, Avg10: 230.33, Epsilon: 0.110
# Episode 450/600, Reward: 25.30, Avg10: 210.57, Epsilon: 0.105
# Episode 460/600, Reward: 246.46, Avg10: 237.12, Epsilon: 0.100
# Episode 470/600, Reward: 257.06, Avg10: 249.18, Epsilon: 0.095
# Episode 480/600, Reward: 254.04, Avg10: 264.92, Epsilon: 0.090
# Episode 490/600, Reward: 56.20, Avg10: 238.92, Epsilon: 0.086
# Episode 500/600, Reward: 257.68, Avg10: 217.91, Epsilon: 0.082
# Episode 510/600, Reward: 280.12, Avg10: 266.67, Epsilon: 0.078
# Episode 520/600, Reward: 256.81, Avg10: 134.01, Epsilon: 0.074
# Episode 530/600, Reward: 139.53, Avg10: 147.18, Epsilon: 0.070
# Episode 540/600, Reward: 256.31, Avg10: 170.44, Epsilon: 0.067
# Episode 550/600, Reward: 14.99, Avg10: 196.33, Epsilon: 0.063
# Episode 560/600, Reward: 199.12, Avg10: 201.09, Epsilon: 0.060
# Episode 570/600, Reward: 228.72, Avg10: 240.03, Epsilon: 0.057
# Episode 580/600, Reward: 295.36, Avg10: 267.91, Epsilon: 0.055
# Episode 590/600, Reward: 236.26, Avg10: 268.33, Epsilon: 0.052
# Episode 600/600, Reward: 282.21, Avg10: 266.05, Epsilon: 0.049
#
# ============================================================
# RUNNING SEED 123
# ============================================================
# Episode 10/600, Reward: -113.75, Avg10: -216.02, Epsilon: 0.951
# Episode 20/600, Reward: -134.61, Avg10: -158.55, Epsilon: 0.905
# Episode 30/600, Reward: -273.59, Avg10: -177.31, Epsilon: 0.860
# Episode 40/600, Reward: -125.30, Avg10: -117.55, Epsilon: 0.818
# Episode 50/600, Reward: -49.90, Avg10: -120.26, Epsilon: 0.778
# Episode 60/600, Reward: -32.83, Avg10: -85.02, Epsilon: 0.740
# Episode 70/600, Reward: -101.86, Avg10: -89.81, Epsilon: 0.704
# Episode 80/600, Reward: 20.72, Avg10: -62.01, Epsilon: 0.670
# Episode 90/600, Reward: -53.09, Avg10: -67.34, Epsilon: 0.637
# Episode 100/600, Reward: 34.06, Avg10: -44.93, Epsilon: 0.606
# Episode 110/600, Reward: -29.40, Avg10: -30.38, Epsilon: 0.576
# Episode 120/600, Reward: -9.08, Avg10: -50.52, Epsilon: 0.548
# Episode 130/600, Reward: -84.62, Avg10: -51.99, Epsilon: 0.521
# Episode 140/600, Reward: 39.02, Avg10: -39.45, Epsilon: 0.496
# Episode 150/600, Reward: -0.29, Avg10: -31.89, Epsilon: 0.471
# Episode 160/600, Reward: -63.92, Avg10: -6.94, Epsilon: 0.448
# Episode 170/600, Reward: -3.49, Avg10: -19.24, Epsilon: 0.427
# Episode 180/600, Reward: -1.66, Avg10: 28.39, Epsilon: 0.406
# Episode 190/600, Reward: 55.52, Avg10: 30.08, Epsilon: 0.386
# Episode 200/600, Reward: 32.42, Avg10: -12.90, Epsilon: 0.367
# Episode 210/600, Reward: -276.53, Avg10: -41.27, Epsilon: 0.349
# Episode 220/600, Reward: 78.67, Avg10: 41.72, Epsilon: 0.332
# Episode 230/600, Reward: 114.46, Avg10: 52.18, Epsilon: 0.316
# Episode 240/600, Reward: 90.46, Avg10: 69.28, Epsilon: 0.300
# Episode 250/600, Reward: 94.79, Avg10: 47.81, Epsilon: 0.286
# Episode 260/600, Reward: 91.45, Avg10: 81.58, Epsilon: 0.272
# Episode 270/600, Reward: 103.25, Avg10: 95.10, Epsilon: 0.258
# Episode 280/600, Reward: 197.02, Avg10: -26.48, Epsilon: 0.246
# Episode 290/600, Reward: -4.47, Avg10: 68.41, Epsilon: 0.234
# Episode 300/600, Reward: 194.50, Avg10: 115.03, Epsilon: 0.222
# Episode 310/600, Reward: 115.95, Avg10: 109.06, Epsilon: 0.211
# Episode 320/600, Reward: 100.79, Avg10: 97.86, Epsilon: 0.201
# Episode 330/600, Reward: 81.51, Avg10: 125.44, Epsilon: 0.191
# Episode 340/600, Reward: 128.29, Avg10: 161.37, Epsilon: 0.182
# Episode 350/600, Reward: 92.00, Avg10: 113.13, Epsilon: 0.173
# Episode 360/600, Reward: 114.90, Avg10: 95.48, Epsilon: 0.165
# Episode 370/600, Reward: 213.64, Avg10: 105.59, Epsilon: 0.157
# Episode 380/600, Reward: 123.49, Avg10: 104.27, Epsilon: 0.149
# Episode 390/600, Reward: 142.37, Avg10: 79.35, Epsilon: 0.142
# Episode 400/600, Reward: 107.69, Avg10: 62.34, Epsilon: 0.135
# Episode 410/600, Reward: 116.70, Avg10: 87.79, Epsilon: 0.128
# Episode 420/600, Reward: 100.50, Avg10: 126.25, Epsilon: 0.122
# Episode 430/600, Reward: 44.84, Avg10: 126.08, Epsilon: 0.116
# Episode 440/600, Reward: 102.02, Avg10: 131.05, Epsilon: 0.110
# Episode 450/600, Reward: 130.90, Avg10: 135.75, Epsilon: 0.105
# Episode 460/600, Reward: 99.47, Avg10: 137.99, Epsilon: 0.100
# Episode 470/600, Reward: 150.56, Avg10: 124.56, Epsilon: 0.095
# Episode 270/600, Reward: 14.41, Avg10: 150.02, Epsilon: 0.258
# Episode 280/600, Reward: 197.28, Avg10: 156.80, Epsilon: 0.246
# Episode 290/600, Reward: 276.21, Avg10: 171.16, Epsilon: 0.234
# Episode 300/600, Reward: 187.51, Avg10: 138.96, Epsilon: 0.222
# Episode 310/600, Reward: 264.64, Avg10: 126.02, Epsilon: 0.211
# Episode 320/600, Reward: 234.31, Avg10: 185.09, Epsilon: 0.201
# Episode 330/600, Reward: 279.49, Avg10: 225.89, Epsilon: 0.191
# Episode 340/600, Reward: 258.95, Avg10: 233.94, Epsilon: 0.182
# Episode 350/600, Reward: -46.16, Avg10: 174.38, Epsilon: 0.173
# Episode 360/600, Reward: -2.61, Avg10: 161.03, Epsilon: 0.165
# Episode 370/600, Reward: 184.77, Avg10: 112.83, Epsilon: 0.157
# Episode 380/600, Reward: 275.48, Avg10: 215.17, Epsilon: 0.149
# Episode 390/600, Reward: 295.57, Avg10: 215.80, Epsilon: 0.142
# Episode 400/600, Reward: 245.07, Avg10: 249.25, Epsilon: 0.135
# Episode 410/600, Reward: 271.19, Avg10: 196.46, Epsilon: 0.128
# Episode 420/600, Reward: 295.79, Avg10: 245.25, Epsilon: 0.122
# Episode 430/600, Reward: 6.62, Avg10: 208.33, Epsilon: 0.116
# Episode 440/600, Reward: 243.50, Avg10: 265.10, Epsilon: 0.110
# Episode 450/600, Reward: 24.59, Avg10: 228.64, Epsilon: 0.105
# Episode 460/600, Reward: 276.15, Avg10: 187.30, Epsilon: 0.100
# Episode 470/600, Reward: 258.47, Avg10: 253.67, Epsilon: 0.095
# Episode 480/600, Reward: 247.39, Avg10: 266.94, Epsilon: 0.090
# Episode 490/600, Reward: 275.34, Avg10: 274.90, Epsilon: 0.086
# Episode 500/600, Reward: 271.02, Avg10: 260.11, Epsilon: 0.082
# Episode 510/600, Reward: 238.63, Avg10: 248.30, Epsilon: 0.078
# Episode 520/600, Reward: 291.05, Avg10: 279.28, Epsilon: 0.074
# Episode 530/600, Reward: 301.22, Avg10: 264.79, Epsilon: 0.070
# Episode 540/600, Reward: 229.58, Avg10: 270.32, Epsilon: 0.067
# Episode 550/600, Reward: 268.86, Avg10: 270.90, Epsilon: 0.063
# Episode 560/600, Reward: 56.08, Avg10: 259.65, Epsilon: 0.060
# Episode 570/600, Reward: 242.07, Avg10: 269.14, Epsilon: 0.057
# Episode 580/600, Reward: 223.81, Avg10: 225.50, Epsilon: 0.055
# Episode 590/600, Reward: 303.58, Avg10: 241.53, Epsilon: 0.052
# Episode 600/600, Reward: 223.32, Avg10: 256.45, Epsilon: 0.049
# Episode 10/600, Reward: -108.13, Avg10: -167.08, Epsilon: 0.951
# Episode 20/600, Reward: -21.97, Avg10: -165.33, Epsilon: 0.905
# Episode 30/600, Reward: -85.97, Avg10: -114.01, Epsilon: 0.860
# Episode 40/600, Reward: -71.45, Avg10: -117.07, Epsilon: 0.818
# Episode 50/600, Reward: -107.09, Avg10: -145.90, Epsilon: 0.778
# Episode 240/600, Reward: 54.19, Avg10: 47.30, Epsilon: 0.300
# Episode 250/600, Reward: 78.08, Avg10: 52.57, Epsilon: 0.286
# Episode 260/600, Reward: -111.21, Avg10: 29.38, Epsilon: 0.272
# Episode 270/600, Reward: 111.32, Avg10: 88.13, Epsilon: 0.258
# Episode 280/600, Reward: 55.33, Avg10: 114.61, Epsilon: 0.246
# Episode 290/600, Reward: 126.26, Avg10: 86.97, Epsilon: 0.234
# Episode 300/600, Reward: 89.43, Avg10: 108.98, Epsilon: 0.222
# Episode 310/600, Reward: 230.65, Avg10: 116.10, Epsilon: 0.211
# Episode 320/600, Reward: 113.62, Avg10: 110.27, Epsilon: 0.201
# Episode 330/600, Reward: 93.53, Avg10: 113.82, Epsilon: 0.191
# Episode 340/600, Reward: 223.57, Avg10: 157.57, Epsilon: 0.182
# Episode 350/600, Reward: 166.41, Avg10: 126.30, Epsilon: 0.173
# Episode 360/600, Reward: 113.90, Avg10: 126.19, Epsilon: 0.165
# Episode 370/600, Reward: 116.33, Avg10: 64.23, Epsilon: 0.157
# Episode 380/600, Reward: 37.61, Avg10: 150.06, Epsilon: 0.149
# Episode 390/600, Reward: 135.25, Avg10: 149.06, Epsilon: 0.142
# Episode 400/600, Reward: 120.79, Avg10: 99.86, Epsilon: 0.135
# Episode 410/600, Reward: 194.90, Avg10: 132.47, Epsilon: 0.128
# Episode 420/600, Reward: 118.65, Avg10: 147.67, Epsilon: 0.122
# Episode 430/600, Reward: 111.32, Avg10: 119.07, Epsilon: 0.116
# Episode 440/600, Reward: 67.68, Avg10: 84.41, Epsilon: 0.110
# Episode 450/600, Reward: 123.89, Avg10: 133.89, Epsilon: 0.105
# Episode 460/600, Reward: 121.12, Avg10: 97.95, Epsilon: 0.100
# Episode 470/600, Reward: 120.24, Avg10: 123.60, Epsilon: 0.095
# Episode 480/600, Reward: 121.77, Avg10: 112.45, Epsilon: 0.090
# Episode 490/600, Reward: 24.14, Avg10: 110.77, Epsilon: 0.086
# Episode 500/600, Reward: 68.71, Avg10: 107.78, Epsilon: 0.082
# Episode 510/600, Reward: 131.01, Avg10: 137.92, Epsilon: 0.078
# Episode 520/600, Reward: 180.54, Avg10: 128.86, Epsilon: 0.074
# Episode 530/600, Reward: 114.10, Avg10: 118.86, Epsilon: 0.070
# Episode 540/600, Reward: 123.53, Avg10: 130.11, Epsilon: 0.067
# Episode 550/600, Reward: 243.92, Avg10: 155.54, Epsilon: 0.063
# Episode 560/600, Reward: 226.74, Avg10: 143.77, Epsilon: 0.060
# Episode 570/600, Reward: -2.85, Avg10: 83.96, Epsilon: 0.057
# Episode 580/600, Reward: 3.36, Avg10: -12.65, Epsilon: 0.055
# Episode 590/600, Reward: 81.70, Avg10: 57.35, Epsilon: 0.052
# Episode 600/600, Reward: 11.80, Avg10: 67.04, Epsilon: 0.049
# Episode 10/600, Reward: 2.06, Avg10: -217.83, Epsilon: 0.951
# Episode 20/600, Reward: -378.22, Avg10: -270.66, Epsilon: 0.905
# Episode 210/600, Reward: -46.55, Avg10: 3.90, Epsilon: 0.349
# Episode 220/600, Reward: 37.20, Avg10: 50.82, Epsilon: 0.332
# Episode 230/600, Reward: -46.05, Avg10: 37.17, Epsilon: 0.316
# Episode 240/600, Reward: 189.30, Avg10: 46.22, Epsilon: 0.300
# Episode 250/600, Reward: 246.64, Avg10: 137.31, Epsilon: 0.286
# Episode 260/600, Reward: 96.26, Avg10: 144.48, Epsilon: 0.272
# Episode 270/600, Reward: 156.63, Avg10: 129.62, Epsilon: 0.258
# Episode 280/600, Reward: 131.57, Avg10: 123.62, Epsilon: 0.246
# Episode 290/600, Reward: 129.98, Avg10: 105.80, Epsilon: 0.234
# Episode 300/600, Reward: 9.35, Avg10: 131.26, Epsilon: 0.222
# Episode 310/600, Reward: 136.07, Avg10: 121.66, Epsilon: 0.211
# Episode 320/600, Reward: 214.80, Avg10: 177.52, Epsilon: 0.201
# Episode 330/600, Reward: 229.24, Avg10: 166.31, Epsilon: 0.191
# Episode 340/600, Reward: 37.98, Avg10: 114.54, Epsilon: 0.182
# Episode 350/600, Reward: -22.72, Avg10: 107.33, Epsilon: 0.173
# Episode 360/600, Reward: 235.38, Avg10: 127.57, Epsilon: 0.165
# Episode 370/600, Reward: 77.16, Avg10: 131.03, Epsilon: 0.157
# Episode 380/600, Reward: 209.14, Avg10: 184.58, Epsilon: 0.149
# Episode 390/600, Reward: 203.78, Avg10: 171.00, Epsilon: 0.142
# Episode 400/600, Reward: 277.65, Avg10: 176.68, Epsilon: 0.135
# Episode 410/600, Reward: 261.73, Avg10: 149.34, Epsilon: 0.128
# Episode 420/600, Reward: 203.56, Avg10: 145.40, Epsilon: 0.122
# Episode 430/600, Reward: 247.12, Avg10: 225.13, Epsilon: 0.116
# Episode 440/600, Reward: 241.42, Avg10: 181.19, Epsilon: 0.110
# Episode 450/600, Reward: -33.53, Avg10: 187.57, Epsilon: 0.105
# Episode 460/600, Reward: -8.94, Avg10: 174.57, Epsilon: 0.100
# Episode 470/600, Reward: 234.76, Avg10: 249.16, Epsilon: 0.095
# Episode 480/600, Reward: 259.10, Avg10: 238.39, Epsilon: 0.090
# Episode 490/600, Reward: 311.92, Avg10: 246.43, Epsilon: 0.086
# Episode 500/600, Reward: 252.81, Avg10: 227.91, Epsilon: 0.082
# Episode 510/600, Reward: 206.19, Avg10: 247.99, Epsilon: 0.078
# Episode 520/600, Reward: 232.37, Avg10: 248.50, Epsilon: 0.074
# Episode 530/600, Reward: 263.77, Avg10: 258.53, Epsilon: 0.070
# Episode 540/600, Reward: 293.39, Avg10: 261.29, Epsilon: 0.067
# Episode 550/600, Reward: 263.48, Avg10: 248.27, Epsilon: 0.063
# Episode 560/600, Reward: 253.34, Avg10: 216.06, Epsilon: 0.060
# Episode 570/600, Reward: 280.69, Avg10: 251.88, Epsilon: 0.057
# Episode 580/600, Reward: 289.89, Avg10: 261.62, Epsilon: 0.055
# Episode 590/600, Reward: 278.37, Avg10: 262.68, Epsilon: 0.052
# Episode 600/600, Reward: 198.82, Avg10: 232.47, Epsilon: 0.049
#
# ============================================================
# RUNNING SEED 789
# ============================================================
# Episode 10/600, Reward: -93.40, Avg10: -263.11, Epsilon: 0.951
# Episode 20/600, Reward: -342.89, Avg10: -211.22, Epsilon: 0.905
# Episode 30/600, Reward: -142.68, Avg10: -193.09, Epsilon: 0.860
# Episode 40/600, Reward: -126.10, Avg10: -125.09, Epsilon: 0.818
# Episode 50/600, Reward: -19.92, Avg10: -117.06, Epsilon: 0.778
# Episode 60/600, Reward: -45.26, Avg10: -83.10, Epsilon: 0.740
# Episode 70/600, Reward: -47.49, Avg10: -80.30, Epsilon: 0.704
# Episode 80/600, Reward: 32.96, Avg10: -40.64, Epsilon: 0.670
# Episode 90/600, Reward: -26.92, Avg10: -42.00, Epsilon: 0.637
# Episode 100/600, Reward: -53.72, Avg10: -40.02, Epsilon: 0.606
# Episode 110/600, Reward: -80.85, Avg10: -70.89, Epsilon: 0.576
# Episode 120/600, Reward: -67.45, Avg10: -61.35, Epsilon: 0.548
# Episode 130/600, Reward: 29.35, Avg10: -65.23, Epsilon: 0.521
# Episode 140/600, Reward: -52.29, Avg10: -62.46, Epsilon: 0.496
# Episode 150/600, Reward: -18.06, Avg10: -37.23, Epsilon: 0.471
# Episode 160/600, Reward: 51.85, Avg10: -4.10, Epsilon: 0.448
# Episode 170/600, Reward: 34.64, Avg10: -51.66, Epsilon: 0.427
# Episode 180/600, Reward: 53.20, Avg10: -10.19, Epsilon: 0.406
# Episode 190/600, Reward: -16.68, Avg10: -5.06, Epsilon: 0.386
# Episode 200/600, Reward: -55.79, Avg10: 21.06, Epsilon: 0.367
# Episode 210/600, Reward: 104.82, Avg10: 45.59, Epsilon: 0.349
# Episode 220/600, Reward: 52.11, Avg10: 41.10, Epsilon: 0.332
# Episode 230/600, Reward: 243.71, Avg10: 75.40, Epsilon: 0.316
# Episode 240/600, Reward: 20.49, Avg10: 30.44, Epsilon: 0.300
# Episode 250/600, Reward: 85.07, Avg10: 28.67, Epsilon: 0.286
# Episode 260/600, Reward: -18.09, Avg10: 87.55, Epsilon: 0.272
# Episode 270/600, Reward: 109.07, Avg10: 79.14, Epsilon: 0.258
# Episode 280/600, Reward: 85.25, Avg10: 65.63, Epsilon: 0.246
# Episode 290/600, Reward: 79.50, Avg10: 116.49, Epsilon: 0.234
# Episode 300/600, Reward: 89.43, Avg10: 106.87, Epsilon: 0.222
# Episode 310/600, Reward: -21.31, Avg10: 54.24, Epsilon: 0.211
# Episode 320/600, Reward: 110.38, Avg10: 34.77, Epsilon: 0.201
# Episode 330/600, Reward: 192.53, Avg10: 73.46, Epsilon: 0.191
# Episode 340/600, Reward: -26.50, Avg10: 97.46, Epsilon: 0.182
# Episode 350/600, Reward: 98.89, Avg10: 118.67, Epsilon: 0.173
# Episode 360/600, Reward: 48.41, Avg10: 157.02, Epsilon: 0.165
# Episode 370/600, Reward: 109.20, Avg10: 142.87, Epsilon: 0.157
# Episode 380/600, Reward: 114.57, Avg10: 130.64, Epsilon: 0.149
# Episode 390/600, Reward: 12.21, Avg10: 130.87, Epsilon: 0.142
# Episode 400/600, Reward: 0.77, Avg10: 97.69, Epsilon: 0.135
# Episode 410/600, Reward: 124.95, Avg10: 75.33, Epsilon: 0.128
# Episode 420/600, Reward: 274.62, Avg10: 121.58, Epsilon: 0.122
# Episode 430/600, Reward: 248.12, Avg10: 134.94, Epsilon: 0.116
# Episode 440/600, Reward: 108.19, Avg10: 74.70, Epsilon: 0.110
# Episode 450/600, Reward: 125.62, Avg10: 128.49, Epsilon: 0.105
# Episode 460/600, Reward: 223.72, Avg10: 110.88, Epsilon: 0.100
# Episode 470/600, Reward: 100.62, Avg10: 141.15, Epsilon: 0.095
# Episode 480/600, Reward: 205.74, Avg10: 134.67, Epsilon: 0.090
# Episode 490/600, Reward: 136.00, Avg10: 161.83, Epsilon: 0.086
# Episode 500/600, Reward: 156.12, Avg10: 166.99, Epsilon: 0.082
# Episode 510/600, Reward: 230.32, Avg10: 167.46, Epsilon: 0.078
# Episode 520/600, Reward: 207.48, Avg10: 140.42, Epsilon: 0.074
# Episode 530/600, Reward: 66.96, Avg10: 149.24, Epsilon: 0.070
# Episode 540/600, Reward: 101.57, Avg10: 160.27, Epsilon: 0.067
# Episode 550/600, Reward: 62.82, Avg10: 120.86, Epsilon: 0.063
# Episode 560/600, Reward: 93.38, Avg10: 70.06, Epsilon: 0.060
# Episode 570/600, Reward: 180.86, Avg10: 58.89, Epsilon: 0.057
# Episode 580/600, Reward: 84.49, Avg10: 79.97, Epsilon: 0.055
# Episode 590/600, Reward: 133.77, Avg10: 70.53, Epsilon: 0.052
# Episode 600/600, Reward: 209.81, Avg10: 131.13, Epsilon: 0.049
# Episode 10/600, Reward: -229.22, Avg10: -333.96, Epsilon: 0.951
# Episode 20/600, Reward: -310.27, Avg10: -245.44, Epsilon: 0.905
# Episode 30/600, Reward: -232.73, Avg10: -244.01, Epsilon: 0.860
# Episode 40/600, Reward: -67.36, Avg10: -102.39, Epsilon: 0.818
# Episode 50/600, Reward: -79.29, Avg10: -87.67, Epsilon: 0.778
# Episode 60/600, Reward: -131.87, Avg10: -76.16, Epsilon: 0.740
# Episode 70/600, Reward: -47.39, Avg10: -74.50, Epsilon: 0.704
# Episode 80/600, Reward: -68.16, Avg10: -63.79, Epsilon: 0.670
# Episode 90/600, Reward: -104.58, Avg10: -69.50, Epsilon: 0.637
# Episode 100/600, Reward: -46.40, Avg10: -61.12, Epsilon: 0.606
# Episode 110/600, Reward: -29.38, Avg10: -54.92, Epsilon: 0.576
# Episode 120/600, Reward: -189.76, Avg10: -72.50, Epsilon: 0.548
# Episode 130/600, Reward: -48.86, Avg10: -43.09, Epsilon: 0.521
# Episode 140/600, Reward: -42.87, Avg10: -36.32, Epsilon: 0.496
# Episode 150/600, Reward: -7.60, Avg10: -35.12, Epsilon: 0.471
# Episode 160/600, Reward: -31.58, Avg10: -27.60, Epsilon: 0.448
# Episode 170/600, Reward: -0.92, Avg10: -19.74, Epsilon: 0.427
# Episode 180/600, Reward: 27.39, Avg10: -3.36, Epsilon: 0.406
# Episode 190/600, Reward: -31.61, Avg10: 19.47, Epsilon: 0.386
# Episode 200/600, Reward: 26.28, Avg10: 6.59, Epsilon: 0.367
# Episode 210/600, Reward: -180.26, Avg10: -13.27, Epsilon: 0.349
# Episode 220/600, Reward: 287.88, Avg10: 61.35, Epsilon: 0.332
# Episode 230/600, Reward: -22.51, Avg10: 26.89, Epsilon: 0.316
# Episode 240/600, Reward: -5.06, Avg10: -0.97, Epsilon: 0.300
# Episode 250/600, Reward: 9.13, Avg10: 61.08, Epsilon: 0.286
# Episode 260/600, Reward: -7.64, Avg10: 109.56, Epsilon: 0.272
# Episode 270/600, Reward: 45.61, Avg10: 200.81, Epsilon: 0.258
# Episode 280/600, Reward: 267.49, Avg10: 194.46, Epsilon: 0.246
# Episode 290/600, Reward: 249.75, Avg10: 179.81, Epsilon: 0.234
# Episode 300/600, Reward: 285.54, Avg10: 228.88, Epsilon: 0.222
# Episode 310/600, Reward: 238.77, Avg10: 191.33, Epsilon: 0.211
# Episode 320/600, Reward: 257.17, Avg10: 250.78, Epsilon: 0.201
# Episode 330/600, Reward: 47.74, Avg10: 223.76, Epsilon: 0.191
# Episode 340/600, Reward: 281.24, Avg10: 174.96, Epsilon: 0.182
# Episode 350/600, Reward: 295.39, Avg10: 210.64, Epsilon: 0.173
# Episode 360/600, Reward: 66.33, Avg10: 114.87, Epsilon: 0.165
# Episode 370/600, Reward: 18.66, Avg10: 177.63, Epsilon: 0.157
# Episode 380/600, Reward: 15.92, Avg10: 125.91, Epsilon: 0.149
# Episode 390/600, Reward: 293.85, Avg10: 171.89, Epsilon: 0.142
# Episode 400/600, Reward: 43.31, Avg10: 88.86, Epsilon: 0.135
# Episode 410/600, Reward: 68.96, Avg10: 135.53, Epsilon: 0.128
# Episode 420/600, Reward: 265.73, Avg10: 108.37, Epsilon: 0.122
# Episode 430/600, Reward: 25.81, Avg10: 161.04, Epsilon: 0.116
# Episode 440/600, Reward: 242.71, Avg10: 189.21, Epsilon: 0.110
# Episode 450/600, Reward: 66.30, Avg10: 136.78, Epsilon: 0.105
# Episode 460/600, Reward: 266.52, Avg10: 140.12, Epsilon: 0.100
# Episode 470/600, Reward: 269.26, Avg10: 220.43, Epsilon: 0.095
# Episode 480/600, Reward: 292.70, Avg10: 247.82, Epsilon: 0.090
# Episode 490/600, Reward: 252.87, Avg10: 207.94, Epsilon: 0.086
# Episode 500/600, Reward: 274.58, Avg10: 219.51, Epsilon: 0.082
# Episode 510/600, Reward: 14.84, Avg10: 224.72, Epsilon: 0.078
# Episode 520/600, Reward: 288.73, Avg10: 218.15, Epsilon: 0.074
# Episode 530/600, Reward: 254.15, Avg10: 103.92, Epsilon: 0.070
# Episode 540/600, Reward: 252.16, Avg10: 209.28, Epsilon: 0.067
# Episode 550/600, Reward: 231.58, Avg10: 215.27, Epsilon: 0.063
# Episode 560/600, Reward: 274.43, Avg10: 238.73, Epsilon: 0.060
# Episode 360/600, Reward: -2.68, Avg10: 96.06, Epsilon: 0.165
# Episode 370/600, Reward: 282.58, Avg10: 162.19, Epsilon: 0.157
# Episode 380/600, Reward: -208.04, Avg10: 172.38, Epsilon: 0.149
# Episode 390/600, Reward: 261.89, Avg10: 202.29, Epsilon: 0.142
# Episode 400/600, Reward: 228.98, Avg10: 204.14, Epsilon: 0.135
# Episode 410/600, Reward: 19.77, Avg10: 148.25, Epsilon: 0.128
# Episode 420/600, Reward: 118.99, Avg10: 234.18, Epsilon: 0.122
# Episode 430/600, Reward: 52.24, Avg10: 167.22, Epsilon: 0.116
# Episode 440/600, Reward: 154.14, Avg10: 213.23, Epsilon: 0.110
# Episode 450/600, Reward: 232.91, Avg10: 239.75, Epsilon: 0.105
# Episode 460/600, Reward: 281.51, Avg10: 243.98, Epsilon: 0.100
# Episode 470/600, Reward: 256.30, Avg10: 197.92, Epsilon: 0.095
# Episode 480/600, Reward: 287.91, Avg10: 181.73, Epsilon: 0.090
# Episode 490/600, Reward: 240.74, Avg10: 233.06, Epsilon: 0.086
# Episode 500/600, Reward: 242.99, Avg10: 241.23, Epsilon: 0.082
# Episode 510/600, Reward: 241.13, Avg10: 235.44, Epsilon: 0.078
# Episode 520/600, Reward: 280.43, Avg10: 266.27, Epsilon: 0.074
# Episode 530/600, Reward: 243.81, Avg10: 223.68, Epsilon: 0.070
# Episode 540/600, Reward: 255.01, Avg10: 252.96, Epsilon: 0.067
# Episode 550/600, Reward: 277.23, Avg10: 260.20, Epsilon: 0.063
# Episode 560/600, Reward: 281.94, Avg10: 265.60, Epsilon: 0.060
# Episode 570/600, Reward: 65.97, Avg10: 257.49, Epsilon: 0.057
# Episode 580/600, Reward: 301.67, Avg10: 273.38, Epsilon: 0.055
# Episode 590/600, Reward: 282.65, Avg10: 277.88, Epsilon: 0.052
# Episode 600/600, Reward: 243.40, Avg10: 261.53, Epsilon: 0.049
#
# ============================================================
# RUNNING SEED 1024
# ============================================================
# Episode 10/600, Reward: -284.08, Avg10: -214.90, Epsilon: 0.951
# Episode 20/600, Reward: -240.85, Avg10: -216.22, Epsilon: 0.905
# Episode 30/600, Reward: -17.02, Avg10: -137.41, Epsilon: 0.860
# Episode 40/600, Reward: -261.97, Avg10: -180.14, Epsilon: 0.818
# Episode 50/600, Reward: -79.63, Avg10: -139.81, Epsilon: 0.778
# Episode 60/600, Reward: -40.83, Avg10: -68.42, Epsilon: 0.740
# Episode 70/600, Reward: -53.58, Avg10: -60.62, Epsilon: 0.704
# Episode 80/600, Reward: -20.12, Avg10: -52.13, Epsilon: 0.670
# Episode 90/600, Reward: -59.57, Avg10: -50.63, Epsilon: 0.637
# Episode 100/600, Reward: -37.73, Avg10: -54.47, Epsilon: 0.606
# Episode 110/600, Reward: -52.63, Avg10: -58.73, Epsilon: 0.576
# Episode 120/600, Reward: 104.25, Avg10: -4.75, Epsilon: 0.548
# Episode 130/600, Reward: 30.38, Avg10: -24.32, Epsilon: 0.521
# Episode 140/600, Reward: -14.80, Avg10: -28.64, Epsilon: 0.496
# Episode 150/600, Reward: -37.20, Avg10: -26.41, Epsilon: 0.471
# Episode 160/600, Reward: -39.25, Avg10: -54.67, Epsilon: 0.448
# Episode 170/600, Reward: 27.10, Avg10: -0.37, Epsilon: 0.427
# Episode 180/600, Reward: -35.12, Avg10: -1.69, Epsilon: 0.406
# Episode 190/600, Reward: 74.06, Avg10: 29.98, Epsilon: 0.386
# Episode 200/600, Reward: 5.13, Avg10: 39.94, Epsilon: 0.367
# Episode 210/600, Reward: 91.33, Avg10: 2.61, Epsilon: 0.349
# Episode 220/600, Reward: -152.91, Avg10: 51.40, Epsilon: 0.332
# Episode 230/600, Reward: 16.58, Avg10: 19.50, Epsilon: 0.316
# Episode 240/600, Reward: 150.73, Avg10: 79.22, Epsilon: 0.300
# Episode 250/600, Reward: 119.42, Avg10: 54.72, Epsilon: 0.286
# Episode 260/600, Reward: 24.54, Avg10: 42.69, Epsilon: 0.272
# Episode 270/600, Reward: 103.66, Avg10: 71.68, Epsilon: 0.258
# Episode 280/600, Reward: 3.16, Avg10: 62.60, Epsilon: 0.246
# Episode 290/600, Reward: -1.12, Avg10: 69.31, Epsilon: 0.234
# Episode 300/600, Reward: 104.40, Avg10: 76.58, Epsilon: 0.222
# Episode 310/600, Reward: 101.92, Avg10: 92.57, Epsilon: 0.211
# Episode 320/600, Reward: 99.09, Avg10: 74.23, Epsilon: 0.201
# Episode 330/600, Reward: 32.58, Avg10: 77.29, Epsilon: 0.191
# Episode 340/600, Reward: 107.62, Avg10: 49.60, Epsilon: 0.182
# Episode 350/600, Reward: 135.22, Avg10: 116.33, Epsilon: 0.173
# Episode 360/600, Reward: 6.15, Avg10: 81.64, Epsilon: 0.165
# Episode 370/600, Reward: 163.74, Avg10: 118.04, Epsilon: 0.157
# Episode 380/600, Reward: 130.30, Avg10: 98.10, Epsilon: 0.149
# Episode 390/600, Reward: 147.22, Avg10: 70.84, Epsilon: 0.142
# Episode 400/600, Reward: 134.27, Avg10: 148.57, Epsilon: 0.135
# Episode 410/600, Reward: -163.04, Avg10: 69.67, Epsilon: 0.128
# Episode 420/600, Reward: 232.92, Avg10: 101.50, Epsilon: 0.122
# Episode 430/600, Reward: 80.14, Avg10: 76.49, Epsilon: 0.116
# Episode 440/600, Reward: 87.68, Avg10: 85.51, Epsilon: 0.110
# Episode 450/600, Reward: -89.02, Avg10: 38.40, Epsilon: 0.105
# Episode 460/600, Reward: 78.12, Avg10: 116.70, Epsilon: 0.100
# Episode 470/600, Reward: 69.11, Avg10: 89.06, Epsilon: 0.095
# Episode 480/600, Reward: 216.50, Avg10: 161.32, Epsilon: 0.090
# Episode 490/600, Reward: 238.80, Avg10: 131.33, Epsilon: 0.086
# Episode 500/600, Reward: 150.96, Avg10: 120.56, Epsilon: 0.082
# Episode 510/600, Reward: 6.32, Avg10: 109.11, Epsilon: 0.078
# Episode 520/600, Reward: 94.17, Avg10: 143.37, Epsilon: 0.074
# Episode 530/600, Reward: 138.23, Avg10: 118.79, Epsilon: 0.070
# Episode 120/600, Reward: -18.96, Avg10: -36.41, Epsilon: 0.548
# Episode 130/600, Reward: -37.34, Avg10: -37.83, Epsilon: 0.521
# Episode 140/600, Reward: -33.78, Avg10: -24.52, Epsilon: 0.496
# Episode 150/600, Reward: 30.01, Avg10: -33.38, Epsilon: 0.471
# Episode 160/600, Reward: -7.88, Avg10: -34.90, Epsilon: 0.448
# Episode 170/600, Reward: 12.45, Avg10: -23.99, Epsilon: 0.427
# Episode 180/600, Reward: -10.84, Avg10: -12.73, Epsilon: 0.406
# Episode 190/600, Reward: -25.04, Avg10: -18.04, Epsilon: 0.386
# Episode 200/600, Reward: 90.23, Avg10: -5.60, Epsilon: 0.367
# Episode 210/600, Reward: 3.81, Avg10: -12.25, Epsilon: 0.349
# Episode 220/600, Reward: 31.67, Avg10: -2.73, Epsilon: 0.332
# Episode 230/600, Reward: 7.43, Avg10: 3.22, Epsilon: 0.316
# Episode 240/600, Reward: 148.46, Avg10: 43.61, Epsilon: 0.300
# Episode 250/600, Reward: 69.61, Avg10: 47.76, Epsilon: 0.286
# Episode 260/600, Reward: -0.28, Avg10: 12.29, Epsilon: 0.272
# Episode 270/600, Reward: 75.71, Avg10: 105.51, Epsilon: 0.258
# Episode 280/600, Reward: 71.51, Avg10: 46.28, Epsilon: 0.246
# Episode 290/600, Reward: 67.37, Avg10: 93.07, Epsilon: 0.234
# Episode 300/600, Reward: -213.54, Avg10: 58.82, Epsilon: 0.222
# Episode 310/600, Reward: 152.94, Avg10: 125.50, Epsilon: 0.211
# Episode 320/600, Reward: 201.14, Avg10: 98.61, Epsilon: 0.201
# Episode 330/600, Reward: 194.29, Avg10: 177.97, Epsilon: 0.191
# Episode 340/600, Reward: 60.95, Avg10: 88.72, Epsilon: 0.182
# Episode 350/600, Reward: 123.60, Avg10: 51.41, Epsilon: 0.173
# Episode 360/600, Reward: 193.97, Avg10: 145.80, Epsilon: 0.165
# Episode 370/600, Reward: 245.27, Avg10: 142.10, Epsilon: 0.157
# Episode 380/600, Reward: 234.06, Avg10: 194.86, Epsilon: 0.149
# Episode 390/600, Reward: 240.30, Avg10: 179.12, Epsilon: 0.142
# Episode 400/600, Reward: 220.42, Avg10: 217.63, Epsilon: 0.135
# Episode 410/600, Reward: 261.55, Avg10: 159.68, Epsilon: 0.128
# Episode 420/600, Reward: -53.73, Avg10: 137.77, Epsilon: 0.122
# Episode 430/600, Reward: 266.52, Avg10: 191.10, Epsilon: 0.116
# Episode 440/600, Reward: 237.18, Avg10: 204.70, Epsilon: 0.110
# Episode 450/600, Reward: 257.15, Avg10: 244.72, Epsilon: 0.105
# Episode 460/600, Reward: 252.55, Avg10: 237.86, Epsilon: 0.100
# Episode 470/600, Reward: 6.74, Avg10: 129.11, Epsilon: 0.095
# Episode 480/600, Reward: 250.38, Avg10: 176.08, Epsilon: 0.090
# Episode 490/600, Reward: 261.67, Avg10: 197.50, Epsilon: 0.086
# Episode 500/600, Reward: 276.94, Avg10: 198.13, Epsilon: 0.082
# Episode 510/600, Reward: 273.10, Avg10: 191.96, Epsilon: 0.078
# Episode 520/600, Reward: 96.32, Avg10: 226.23, Epsilon: 0.074
# Episode 530/600, Reward: 282.28, Avg10: 200.86, Epsilon: 0.070
# Episode 540/600, Reward: -67.41, Avg10: 78.36, Epsilon: 0.067
# Episode 550/600, Reward: 299.77, Avg10: 140.30, Epsilon: 0.063
# Episode 560/600, Reward: 264.52, Avg10: 161.06, Epsilon: 0.060
# Episode 570/600, Reward: 296.89, Avg10: 236.45, Epsilon: 0.057
# Episode 580/600, Reward: 259.30, Avg10: 217.01, Epsilon: 0.055
# Episode 590/600, Reward: 300.97, Avg10: 255.82, Epsilon: 0.052
# Episode 600/600, Reward: 290.89, Avg10: 264.58, Epsilon: 0.049
#
# ============================================================
# ALL SEEDS COMPLETED!
# ============================================================

# %%
import matplotlib.pyplot as plt

def plot_with_confidence(results, window=20):
    """Plot mean reward with shaded std across seeds."""
    fig, ax = plt.subplots(figsize=(12, 6))
    
    colors = {'base': 'green', 'adaptive': 'blue', 'full': 'red'}
    labels = {'base': 'Base Agent (3 actions)', 
              'adaptive': 'Adaptive Agent (fine-tuned)', 
              'full': 'Full Action (4 actions)'}
    
    for agent_type in ['base', 'adaptive', 'full']:
        rewards = np.array(results[agent_type]['rewards'])  # Shape: (n_seeds, n_episodes)
        
        # Compute moving average for each seed
        smoothed = []
        for r in rewards:
            ma = np.convolve(r, np.ones(window)/window, mode='valid')
            smoothed.append(ma)
        smoothed = np.array(smoothed)
        
        mean = smoothed.mean(axis=0)
        std = smoothed.std(axis=0)
        episodes = range(window-1, window-1 + len(mean))
        
        ax.plot(episodes, mean, color=colors[agent_type], lw=2, label=labels[agent_type])
        ax.fill_between(episodes, mean - std, mean + std, color=colors[agent_type], alpha=0.2)
    
    ax.set_xlabel('Episode', fontsize=12)
    ax.set_ylabel('Reward (Moving Average)', fontsize=12)
    ax.set_title(f'Training Comparison Across {len(SEEDS)} Seeds (Mean ± Std)', fontsize=14, fontweight='bold')
    ax.legend(fontsize=10)
    ax.grid(alpha=0.3)
    ax.axhline(y=200, color='gray', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.savefig('multi_seed_comparison.png', dpi=150)
    plt.show()

# Print final statistics
def print_final_stats(results, last_n=50):
    print("\n" + "="*80)
    print(f"FINAL PERFORMANCE (Last {last_n} Episodes, {len(SEEDS)} Seeds)")
    print("="*80)
    
    for agent_type in ['base', 'adaptive', 'full']:
        rewards = np.array(results[agent_type]['rewards'])
        final_rewards = rewards[:, -last_n:]  # Last N episodes for each seed
        
        mean_per_seed = final_rewards.mean(axis=1)  # Mean for each seed
        overall_mean = mean_per_seed.mean()
        overall_std = mean_per_seed.std()
        
        print(f"\n{agent_type.upper():12} | Mean: {overall_mean:7.2f} ± {overall_std:.2f}")

plot_with_confidence(all_results)
print_final_stats(all_results)
# Out:
# ================================================================================
# FINAL PERFORMANCE (Last 50 Episodes, 5 Seeds)
# ================================================================================
#
# BASE         | Mean:  112.77 ± 32.09
#
# ADAPTIVE     | Mean:  189.56 ± 50.41
#
# FULL         | Mean:  247.66 ± 12.85
